# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
#%pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.754070, train error 69.90,  test loss 1.778813, test error 73.80
# Epoch     1, train loss 1.677337, train error 67.12,  test loss 1.702340, test error 68.90
# Epoch     2, train loss 1.654754, train error 66.80,  test loss 1.693345, test error 69.50
# Epoch     3, train loss 1.641526, train error 65.53,  test loss 1.683755, test error 68.90
# Epoch     4, train loss 1.636667, train error 65.05,  test loss 1.682164, test error 68.00
# Epoch     5, train loss 1.627248, train error 64.88,  test loss 1.676583, test error 70.60
# Epoch     6, train loss 1.617537, train error 64.62,  test loss 1.668233, test error 68.70
# Epoch     7, train loss 1.619338, train error 64.43,  test loss 1.660667, test error 68.90
# Epoch     8, train loss 1.620032, train error 64.10,  test loss 1.670402, test error 69.00
# Epoch     9, train loss 1.606893, train error 63.38,  test loss 1.673011, test error 69.20
# Epoch    10, train loss 1.600077, train error 62.50,  test loss 1.651446, test error 65.80
# Epoch    11, train loss 1.600119, train error 63.50,  test loss 1.663816, test error 67.70
# Epoch    12, train loss 1.599126, train error 62.97,  test loss 1.658793, test error 68.20
# Epoch    13, train loss 1.599695, train error 63.45,  test loss 1.658574, test error 66.70
# Epoch    14, train loss 1.596740, train error 63.12,  test loss 1.654487, test error 66.80
# Epoch    15, train loss 1.598131, train error 63.03,  test loss 1.655196, test error 66.50
# Epoch    16, train loss 1.595939, train error 63.25,  test loss 1.661705, test error 67.00
# Epoch    17, train loss 1.597136, train error 63.45,  test loss 1.656197, test error 66.90
# Epoch    18, train loss 1.596833, train error 62.62,  test loss 1.666226, test error 67.60
# Epoch    19, train loss 1.599096, train error 62.92,  test loss 1.665364, test error 67.90
# Epoch    20, train loss 1.591775, train error 62.35,  test loss 1.651086, test error 66.70
# Epoch    21, train loss 1.591366, train error 62.35,  test loss 1.652586, test error 65.80
# Epoch    22, train loss 1.591650, train error 62.25,  test loss 1.652329, test error 66.60
# Epoch    23, train loss 1.591978, train error 62.90,  test loss 1.653877, test error 66.60
# Epoch    24, train loss 1.590627, train error 62.60,  test loss 1.653228, test error 66.70
# Epoch    25, train loss 1.590796, train error 63.00,  test loss 1.653413, test error 67.80
# Epoch    26, train loss 1.590585, train error 62.38,  test loss 1.653631, test error 66.90
# Epoch    27, train loss 1.589881, train error 62.67,  test loss 1.653050, test error 66.80
# Epoch    28, train loss 1.589791, train error 62.80,  test loss 1.653898, test error 67.10
# Epoch    29, train loss 1.590340, train error 62.25,  test loss 1.652373, test error 67.20
# Epoch    30, train loss 1.589328, train error 62.45,  test loss 1.652973, test error 66.40
# Epoch    31, train loss 1.589297, train error 62.60,  test loss 1.654101, test error 67.00
# Epoch    32, train loss 1.589115, train error 62.70,  test loss 1.652723, test error 67.40
# Epoch    33, train loss 1.589165, train error 62.75,  test loss 1.653220, test error 65.90
# Epoch    34, train loss 1.589146, train error 62.62,  test loss 1.653698, test error 66.70
# Epoch    35, train loss 1.588899, train error 62.53,  test loss 1.653868, test error 66.50
# Epoch    36, train loss 1.588880, train error 62.85,  test loss 1.652699, test error 66.50
# Epoch    37, train loss 1.588952, train error 62.58,  test loss 1.653256, test error 66.30
# Epoch    38, train loss 1.588740, train error 62.50,  test loss 1.652014, test error 66.40
# Epoch    39, train loss 1.588703, train error 62.75,  test loss 1.653440, test error 66.50
# Epoch    40, train loss 1.588630, train error 62.53,  test loss 1.653742, test error 67.30
# Epoch    41, train loss 1.588524, train error 62.67,  test loss 1.653304, test error 66.70
# Epoch    42, train loss 1.588511, train error 62.67,  test loss 1.652911, test error 67.00
# Epoch    43, train loss 1.588462, train error 62.70,  test loss 1.652015, test error 66.20
# Epoch    44, train loss 1.588438, train error 62.83,  test loss 1.652763, test error 66.90
# Epoch    45, train loss 1.588418, train error 62.75,  test loss 1.652713, test error 66.90
# Epoch    46, train loss 1.588435, train error 62.60,  test loss 1.654199, test error 66.90
# Epoch    47, train loss 1.588367, train error 62.90,  test loss 1.653186, test error 66.40
# Epoch    48, train loss 1.588390, train error 62.72,  test loss 1.652757, test error 66.70
# Epoch    49, train loss 1.588312, train error 62.58,  test loss 1.653563, test error 66.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
